# %%
# The first step is to train the models

# %run model_training.py
# Out:
# Fitting 3 folds for each of 3888 candidates, totalling 11664 fits
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.8; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=50, subsample=0.8; total time=   0.0s
# ...

# %%
# Run this to get the predictions. Make sure to edit the data_frame in get_predictions.py using your physical and logical error requirements.

# %run get_predictions.py
# Out:
# Predictions for 'd': [ 7.  7. 21. 23. 25.]
# Predictions for 'r': [25. 17. 67. 67. 67.]
# Time taken for Model 1 prediction: 0.0049 seconds
# /Users/avimitachatterjee/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
